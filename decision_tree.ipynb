# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nba_games_cleaned_with_avgs.csv')
df.head()
# Out:
#    Unnamed: 0        date team  total team_opp  total_opp    won    fg   fga  \
# 0           0  2015-10-27  NOP     95      GSW        111  False  35.0  83.0
# 1           1  2015-10-27  CLE     95      CHI         97  False  38.0  94.0
# 2           2  2015-10-27  DET    106      ATL         94   True  37.0  96.0
# 3           3  2015-10-27  ATL     94      DET        106  False  37.0  82.0
# 4           4  2015-10-27  CHI     97      CLE         95   True  37.0  87.0
#
#      fg%  ...  season_avg_ft%  season_avg_orb  season_avg_drb  season_avg_trb  \
# 0  0.422  ...           0.704             8.0            25.0            33.0
# 1  0.404  ...           0.588            11.0            39.0            50.0
# 2  0.385  ...           0.769            23.0            36.0            59.0
# 3  0.451  ...           0.800             7.0            33.0            40.0
# 4  0.425  ...           0.696             7.0            40.0            47.0
#
# ...
